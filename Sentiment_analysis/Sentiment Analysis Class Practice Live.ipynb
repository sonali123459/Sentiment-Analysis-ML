# %%
# !pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/624.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/624.3 kB ? eta -:--:--
#    ------------------------------- ------ 524.3/624.3 kB 656.7 kB/s eta 0:00:01
#    -------------------------------------- 624.3/624.3 kB 633.6 kB/s eta 0:00:00
# ...

# %%
from textblob import TextBlob

# %%
text="I am very happy today"
textanaly=TextBlob(text)
textanaly
# Out:
# TextBlob("I am very happy today")

# %%
print(textanaly.sentiment)
# Out:
# Sentiment(polarity=1.0, subjectivity=1.0)

# %%
textanaly.sentiment.polarity
# Out:
# 1.0

# %%
textanaly.sentiment.subjectivity
# Out:
# 1.0

# %%
feedback=input('Submit your review: ')
feedanay=TextBlob(feedback)
feedanay.sentiment
# Out:
# Submit your review:  the movie is not good
# Sentiment(polarity=-0.35, subjectivity=0.6000000000000001)
